# %%
import numpy as np
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute
import random
import tkinter as tk
from tkinter import *
import itertools
from itertools import permutations
import cmath

# %%
qr = QuantumRegister(1)
cr = ClassicalRegister(1)
circ = QuantumCircuit(qr,cr)

# %%
def get_gates_random(n):
    gate_type = ["H", "I", "X", "Y", "Z"]
    sqe = list(range(0, n))
    return(random.sample(gate_type, 2), random.sample(sqe, 2))

# %%
from qiskit import BasicAer
backend_sv_sim = BasicAer.get_backend('statevector_simulator')
backend_sim = BasicAer.get_backend('qasm_simulator')

# %%
def gate_apply(user_input):
    if(user_input) == "I":
        print("")
    if(user_input) == "X":
        circ.x(qr[0])
    if(user_input) == "Y":
        circ.y(qr[0])
    if(user_input) == "Z":
        circ.z(qr[0])
    if(user_input) == "H":
        circ.h(qr[0])

# %%
gate_type = ["H", "I", "X", "Y", "Z"]
perm = itertools.combinations_with_replacement(gate_type, 4)
perm2 = list(perm)
for permute in perm2:
    del qr
    del cr
    del circ
    qr = QuantumRegister(1)
    cr = ClassicalRegister(1)
    circ = QuantumCircuit(qr,cr)
    gate_apply(permute[0])
    gate_apply(permute[1])
    gate_apply(permute[2])
    circ.measure(qr, cr)
    job_sim = execute(circ, backend_sv_sim, shots=1000)
    # Grab the results from the job.
    result_sim = job_sim.result()
    # Obtain the state vector for the quantum circuit
    quantum_state = result_sim.get_statevector(circ, decimals=1)
    # Output the quantum state vector in a manner that contains a comma-delimited string.
    # Execute the circuit on the qasm simulator, running it 1000 times.
    job_sim = execute(circ, backend_sim, shots=1000)
    # Grab the results from the job.
    result_sim = job_sim.result()
    counts = result_sim.get_counts(circ)
    if 1000 not in counts.values():
        print(permute, quantum_state)
    else:
        print(permute, counts)
# Out:
# ('H', 'H', 'H', 'H') [0.7+0.j 0.7+0.j]
# ('H', 'H', 'H', 'I') [0.7+0.j 0.7+0.j]
# ('H', 'H', 'H', 'X') [0.7+0.j 0.7+0.j]
# ('H', 'H', 'H', 'Y') [0.7+0.j 0.7+0.j]
# ('H', 'H', 'H', 'Z') [0.7+0.j 0.7+0.j]
#
# ('H', 'H', 'I', 'I') {'0': 1000}
#
# ('H', 'H', 'I', 'X') {'0': 1000}
#
# ('H', 'H', 'I', 'Y') {'0': 1000}
#
# ('H', 'H', 'I', 'Z') {'0': 1000}
# ('H', 'H', 'X', 'X') {'1': 1000}
# ('H', 'H', 'X', 'Y') {'1': 1000}
# ('H', 'H', 'X', 'Z') {'1': 1000}
# ('H', 'H', 'Y', 'Y') {'1': 1000}
# ('H', 'H', 'Y', 'Z') {'1': 1000}
# ('H', 'H', 'Z', 'Z') {'0': 1000}
#
#
# ('H', 'I', 'I', 'I') [0.7+0.j 0.7+0.j]
#
#
# ('H', 'I', 'I', 'X') [0.7+0.j 0.7+0.j]
#
#
# ('H', 'I', 'I', 'Y') [0.7+0.j 0.7+0.j]
#
#
# ('H', 'I', 'I', 'Z') [0.7+0.j 0.7+0.j]
#
# ('H', 'I', 'X', 'X') [0.7+0.j 0.7+0.j]
#
# ('H', 'I', 'X', 'Y') [0.7+0.j 0.7+0.j]
#
# ('H', 'I', 'X', 'Z') [0.7+0.j 0.7+0.j]
#
# ('H', 'I', 'Y', 'Y') [0.-0.7j 0.+0.7j]
#
# ('H', 'I', 'Y', 'Z') [0.-0.7j 0.+0.7j]
#
# ('H', 'I', 'Z', 'Z') [ 0.7+0.j -0.7+0.j]
# ('H', 'X', 'X', 'X') [0.7+0.j 0.7+0.j]
# ('H', 'X', 'X', 'Y') [0.7+0.j 0.7+0.j]
# ('H', 'X', 'X', 'Z') [0.7+0.j 0.7+0.j]
# ('H', 'X', 'Y', 'Y') [0.-0.7j 0.+0.7j]
# ('H', 'X', 'Y', 'Z') [0.-0.7j 0.+0.7j]
# ('H', 'X', 'Z', 'Z') [ 0.7+0.j -0.7+0.j]
# ('H', 'Y', 'Y', 'Y') [0.7+0.j 0.7+0.j]
# ('H', 'Y', 'Y', 'Z') [0.7+0.j 0.7+0.j]
# ('H', 'Y', 'Z', 'Z') [0.-0.7j 0.-0.7j]
# ('H', 'Z', 'Z', 'Z') [0.7+0.j 0.7+0.j]
#
#
#
# ('I', 'I', 'I', 'I') {'0': 1000}
#
#
#
# ('I', 'I', 'I', 'X') {'0': 1000}
#
#
#
# ('I', 'I', 'I', 'Y') {'0': 1000}
#
#
#
# ('I', 'I', 'I', 'Z') {'0': 1000}
#
#
# ('I', 'I', 'X', 'X') {'1': 1000}
#
#
# ('I', 'I', 'X', 'Y') {'1': 1000}
#
#
# ('I', 'I', 'X', 'Z') {'1': 1000}
#
#
# ('I', 'I', 'Y', 'Y') {'1': 1000}
#
#
# ('I', 'I', 'Y', 'Z') {'1': 1000}
#
#
# ('I', 'I', 'Z', 'Z') {'0': 1000}
#
# ('I', 'X', 'X', 'X') {'0': 1000}
#
# ('I', 'X', 'X', 'Y') {'0': 1000}
#
# ('I', 'X', 'X', 'Z') {'0': 1000}
#
# ('I', 'X', 'Y', 'Y') {'0': 1000}
#
# ('I', 'X', 'Y', 'Z') {'0': 1000}
#
# ('I', 'X', 'Z', 'Z') {'1': 1000}
#
# ('I', 'Y', 'Y', 'Y') {'0': 1000}
#
# ('I', 'Y', 'Y', 'Z') {'0': 1000}
#
# ('I', 'Y', 'Z', 'Z') {'1': 1000}
#
# ('I', 'Z', 'Z', 'Z') {'0': 1000}
# ('X', 'X', 'X', 'X') {'1': 1000}
# ('X', 'X', 'X', 'Y') {'1': 1000}
# ('X', 'X', 'X', 'Z') {'1': 1000}
# ('X', 'X', 'Y', 'Y') {'1': 1000}
# ('X', 'X', 'Y', 'Z') {'1': 1000}
# ('X', 'X', 'Z', 'Z') {'0': 1000}
# ('X', 'Y', 'Y', 'Y') {'1': 1000}
# ('X', 'Y', 'Y', 'Z') {'1': 1000}
# ('X', 'Y', 'Z', 'Z') {'0': 1000}
# ('X', 'Z', 'Z', 'Z') {'1': 1000}
# ('Y', 'Y', 'Y', 'Y') {'1': 1000}
# ('Y', 'Y', 'Y', 'Z') {'1': 1000}
# ('Y', 'Y', 'Z', 'Z') {'0': 1000}
# ('Y', 'Z', 'Z', 'Z') {'1': 1000}
# ('Z', 'Z', 'Z', 'Z') {'0': 1000}
